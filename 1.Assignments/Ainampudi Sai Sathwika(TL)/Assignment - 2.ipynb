# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50, VGG16
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Load CIFAR-10 dataset

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %% [markdown]
# Normalize pixel values to between 0 and 1

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %% [markdown]
# One-hot encode the labels

# %%
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# Choose between ResNet50 or VGG16

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Freeze the convolutional base

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# Add custom dense layers

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

# %% [markdown]
# Create the final model

# %%
model = Model(inputs=base_model.input, outputs=predictions)

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train the model

# %%
history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=64,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 776s 990ms/step - accuracy: 0.4733 - loss: 1.5028 - val_accuracy: 0.5598 - val_loss: 1.2522
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 767s 945ms/step - accuracy: 0.5886 - loss: 1.1754 - val_accuracy: 0.5898 - val_loss: 1.1706
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 762s 971ms/step - accuracy: 0.6176 - loss: 1.0947 - val_accuracy: 0.5965 - val_loss: 1.1463
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 802s 971ms/step - accuracy: 0.6376 - loss: 1.0396 - val_accuracy: 0.6003 - val_loss: 1.1379
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 782s 946ms/step - accuracy: 0.6508 - loss: 0.9954 - val_accuracy: 0.6075 - val_loss: 1.1129
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 740s 944ms/step - accuracy: 0.6655 - loss: 0.9538 - val_accuracy: 0.6215 - val_loss: 1.0867
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 761s 969ms/step - accuracy: 0.6876 - loss: 0.8938 - val_accuracy: 0.6209 - val_loss: 1.0893
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 780s 941ms/step - accuracy: 0.6901 - loss: 0.8809 - val_accuracy: 0.6154 - val_loss: 1.1066
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 767s 973ms/step - accuracy: 0.7111 - loss: 0.8327 - val_accuracy: 0.6197 - val_loss: 1.1095
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 778s 942ms/step - accuracy: 0.7204 - loss: 0.7984 - val_accuracy: 0.6177 - val_loss: 1.1258

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Evaluate the model on the test set

# %%
y_pred = model.predict(x_test)
y_pred_classes = y_pred.argmax(axis=-1)
y_true = y_test.argmax(axis=-1)

# %% [markdown]
# Calculate accuracy, precision, and recall

# %%
accuracy = accuracy_score(y_true, y_pred_classes)
precision = precision_score(y_true, y_pred_classes, average='weighted')
recall = recall_score(y_true, y_pred_classes, average='weighted')

# %%
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")

# %% [markdown]
# Display classification report

# %%
print(classification_report(y_true, y_pred_classes))
